# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/BasiaSDA/projekt-klasyfikacja/main/df1.csv')
df1.head()
# Out:
#    EmployeeNumber   Age BusinessTravel  DailyRate              Department  \
# 0             104  30.0  Travel_Rarely      852.0  Research & Development
# 1            1638  38.0  Travel_Rarely      397.0  Research & Development
# 2             164  26.0  Travel_Rarely      841.0  Research & Development
# 3             395  28.0  Travel_Rarely     1117.0  Research & Development
# 4              53  35.0  Travel_Rarely      464.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0               1.0        1.0  Life Sciences            1.0
# 1               2.0        2.0        Medical            1.0
# 2               6.0        3.0          Other            1.0
# 3               8.0        2.0  Life Sciences            1.0
# 4               4.0        2.0          Other            1.0
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                      4.0    Male        55.0             2.0       2.0
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/BasiaSDA/projekt-klasyfikacja/main/df2.csv')
df2.head()
# Out:
#    EmployeeNumber Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0             104      Y      Yes               12.0                3.0
# 1            1638      Y      Yes               19.0                3.0
# 2             164      Y       No               19.0                3.0
# 3             395      Y       No               21.0                4.0
# 4              53      Y       No               12.0                3.0
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                       3.0           80.0               2.0
# 1                       4.0           80.0               1.0
# 2                       3.0           80.0               0.0
# 3                       4.0           80.0               0.0
# 4                       3.0           80.0               1.0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0               10.0                    1.0              2.0            10.0
# ...

# %%
df=df1.merge(df2)
df.head()
# Out:
#    EmployeeNumber   Age BusinessTravel  DailyRate              Department  \
# 0             104  30.0  Travel_Rarely      852.0  Research & Development
# 1            1638  38.0  Travel_Rarely      397.0  Research & Development
# 2             164  26.0  Travel_Rarely      841.0  Research & Development
# 3             395  28.0  Travel_Rarely     1117.0  Research & Development
# 4              53  35.0  Travel_Rarely      464.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0               1.0        1.0  Life Sciences            1.0
# 1               2.0        2.0        Medical            1.0
# 2               6.0        3.0          Other            1.0
# 3               8.0        2.0  Life Sciences            1.0
# 4               4.0        2.0          Other            1.0
#
#    EnvironmentSatisfaction  ... StockOptionLevel  TotalWorkingYears  \
# 0                      4.0  ...              2.0               10.0
# ...

# %%
df.describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     4449.000000  4449.000000  4449.000000       4449.000000
# mean      7956.865588   416.187458   801.017982      33339.433356
# std      17226.922333  1566.205147   405.605362     145352.131423
# min          1.000000    18.000000   102.000000          1.000000
# 25%       1735.000000    31.000000   458.000000          2.000000
# 50%       5902.000000    36.000000   804.000000          8.000000
# 75%       7014.000000    45.000000  1162.000000         17.000000
# max     100146.000000  9890.000000  1499.000000     999590.000000
#
#          Education  EmployeeCount  EnvironmentSatisfaction   HourlyRate  \
# count  4449.000000         4449.0              4449.000000  4449.000000
# mean      2.909867            1.0                 2.719263    65.977073
# std       1.025184            0.0                 1.093263    20.277369
# min       1.000000            1.0                 1.000000    30.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4449 entries, 0 to 4448
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4449 non-null   int64
#  1   Age                       4449 non-null   float64
#  2   BusinessTravel            4449 non-null   object
#  3   DailyRate                 4449 non-null   float64
#  4   Department                4449 non-null   object
#  5   DistanceFromHome          4449 non-null   float64
#  6   Education                 4449 non-null   float64
#  7   EducationField            4449 non-null   object
#  8   EmployeeCount             4449 non-null   float64
#  9   EnvironmentSatisfaction   4449 non-null   float64
#  10  Gender                    4449 non-null   object
#  11  HourlyRate                4449 non-null   float64
#  12  JobInvolvement            4449 non-null   float64
# ...

# %%
df_cat = df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#   BusinessTravel              Department EducationField  Gender  \
# 0  Travel_Rarely  Research & Development  Life Sciences    Male
# 1  Travel_Rarely  Research & Development        Medical  Female
# 2  Travel_Rarely  Research & Development          Other  Female
# 3  Travel_Rarely  Research & Development  Life Sciences  Female
# 4  Travel_Rarely  Research & Development          Other    Male
#
#                   JobRole MaritalStatus Over18 OverTime Attrition
# 0   Laboratory Technician       Married      Y      Yes        No
# 1  Manufacturing Director       Married      Y      Yes        No
# 2      Research Scientist       Married      Y       No        No
# 3      Research Scientist        Single      Y       No        No
# 4   Laboratory Technician      Divorced      Y       No        No

# %%
df_cat.describe()
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            4449                    4449           4449   4449
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             3147                    2916           1823   2681
#
#                 JobRole MaritalStatus Over18 OverTime Attrition
# count              4449          4449   4449     4449      4302
# unique                9             3      1        2         2
# top     Sales Executive       Married      Y       No       Yes
# freq                983          2074   4449     3186      2222

# %%
for column in df_cat.columns:
    print(df_cat[column].unique())
# Out:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ['Research & Development' 'Human Resources' 'Sales']
# ['Life Sciences' 'Medical' 'Other' 'Technical Degree' 'Marketing'
#  'Human Resources']
# ['Male' 'Female']
# ['Laboratory Technician' 'Manufacturing Director' 'Research Scientist'
#  'Human Resources' 'Research Director' 'Sales Representative' 'Manager'
#  'Healthcare Representative' 'Sales Executive']
# ['Married' 'Single' 'Divorced']
# ['Y']
# ['Yes' 'No']
# ['No' 'Yes' nan]

# %%
df_cat[df_cat.Attrition.isna()]
# Out:
#      BusinessTravel              Department EducationField  Gender  \
# 1323  Travel_Rarely  Research & Development        Medical  Female
# 1324  Travel_Rarely  Research & Development  Life Sciences  Female
# 1325  Travel_Rarely                   Sales        Medical  Female
# 1326     Non-Travel                   Sales        Medical    Male
# 1327  Travel_Rarely  Research & Development          Other    Male
# ...             ...                     ...            ...     ...
# 1465     Non-Travel  Research & Development  Life Sciences  Female
# 1466  Travel_Rarely  Research & Development  Life Sciences  Female
# 1467  Travel_Rarely  Research & Development        Medical    Male
# 1468  Travel_Rarely  Research & Development        Medical  Female
# 1469     Non-Travel  Research & Development        Medical    Male
#
#                         JobRole MaritalStatus Over18 OverTime Attrition
# 1323         Research Scientist        Single      Y       No       NaN
# ...

# %%
df.drop(['Over18', 'StandardHours', 'EmployeeCount'], axis=1, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4449 entries, 0 to 4448
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4449 non-null   int64
#  1   Age                       4449 non-null   float64
#  2   BusinessTravel            4449 non-null   object
#  3   DailyRate                 4449 non-null   float64
#  4   Department                4449 non-null   object
#  5   DistanceFromHome          4449 non-null   float64
#  6   Education                 4449 non-null   float64
#  7   EducationField            4449 non-null   object
#  8   EnvironmentSatisfaction   4449 non-null   float64
#  9   Gender                    4449 non-null   object
#  10  HourlyRate                4449 non-null   float64
#  11  JobInvolvement            4449 non-null   float64
#  12  JobLevel                  4449 non-null   float64
# ...

# %%
sns.boxplot(x="TotalWorkingYears", data=df)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears'>

# %%
df[df['TotalWorkingYears']>60]
# Out:
#       EmployeeNumber   Age     BusinessTravel  DailyRate  \
# 1473            5004  38.0      Travel_Rarely      397.0
# 1474            5005  38.0      Travel_Rarely      397.0
# 1475            5006  26.0      Travel_Rarely      841.0
# 1485            5016  34.0  Travel_Frequently      296.0
# 1486            5017  34.0  Travel_Frequently      296.0
# ...              ...   ...                ...        ...
# 4411            7942  33.0      Travel_Rarely      213.0
# 4412            7943  33.0      Travel_Rarely      213.0
# 4440            7971  42.0      Travel_Rarely     1396.0
# 4441            7972  42.0      Travel_Rarely     1396.0
# 4442            7973  42.0      Travel_Rarely     1396.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1473  Research & Development               2.0        2.0        Medical
# 1474  Research & Development               2.0        2.0        Medical
# ...

# %%
df[df['TotalWorkingYears']>60].describe()
# Out:
#        EmployeeNumber         Age    DailyRate  DistanceFromHome   Education  \
# count      256.000000  256.000000   256.000000        256.000000  256.000000
# mean      6407.589844   35.964844   789.507812          9.644531    2.812500
# std        831.338241    8.958003   415.924126          7.838730    0.951779
# min       5004.000000   18.000000   115.000000          1.000000    1.000000
# 25%       5751.750000   29.000000   453.250000          3.000000    2.000000
# 50%       6319.500000   35.500000   721.500000          8.000000    3.000000
# 75%       7101.250000   42.000000  1137.500000         15.000000    3.000000
# max       7973.000000   56.000000  1495.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               256.000000  256.000000      256.000000  256.000000
# mean                  2.742188   68.894531        2.726562    1.925781
# ...

# %%
df[df['Age']>80]
# Out:
#       EmployeeNumber     Age     BusinessTravel  DailyRate  \
# 1479            5010  8825.0      Travel_Rarely     1107.0
# 1480            5011  8825.0      Travel_Rarely     1107.0
# 1499            5030  3628.0  Travel_Frequently      544.0
# 1517            5048  6287.0      Travel_Rarely     1265.0
# 1518            5049  6287.0      Travel_Rarely     1265.0
# ...              ...     ...                ...        ...
# 4414            7945  3437.0      Travel_Rarely     1299.0
# 4415            7946  3437.0      Travel_Rarely     1299.0
# 4443            7974  8823.0      Travel_Rarely      621.0
# 4444            7975  8823.0      Travel_Rarely      621.0
# 4445            7976  8823.0      Travel_Rarely      621.0
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1479         Human Resources               9.0        4.0  Technical Degree
# 1480         Human Resources               9.0        4.0  Technical Degree
# ...

# %%
df[df['Age']>80].describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome   Education  \
# count      298.000000   298.000000   298.000000        298.000000  298.000000
# mean      6576.375839  5701.130872   845.711409          9.859060    2.989933
# std        924.000820  2588.329986   409.249552          8.599601    0.989796
# min       5010.000000  1107.000000   144.000000          1.000000    1.000000
# 25%       5726.500000  3437.000000   504.000000          3.000000    2.000000
# 50%       6772.500000  5565.000000   898.000000          7.000000    3.000000
# 75%       7411.750000  8167.000000  1217.000000         15.750000    4.000000
# max       7976.000000  9890.000000  1492.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               298.000000  298.000000      298.000000  298.000000
# mean                  2.667785   65.332215        2.758389    2.137584
# ...

# %%
df_copy = df[(df['TotalWorkingYears']<60) & (df['Age']<80) & (df['DistanceFromHome']<100) & (df['YearsAtCompany']<60)&
             (df['YearsInCurrentRole']<60) & (df['YearsSinceLastPromotion']<60) & (df['YearsWithCurrManager']<60)]

# %%
df_copy.iloc[:, 0:20].describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     2498.000000  2498.000000  2498.000000       2498.000000
# mean      9088.795837    37.005604   799.656125          9.283427
# std      22915.578098     9.089726   401.148484          8.153055
# min          1.000000    18.000000   102.000000          1.000000
# 25%        966.250000    30.000000   464.000000          2.000000
# 50%       1953.000000    36.000000   801.500000          7.000000
# 75%       6518.750000    43.000000  1156.250000         14.000000
# max     100146.000000    60.000000  1499.000000         29.000000
#
#          Education  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count  2498.000000              2498.000000  2498.000000     2498.000000
# mean      2.920336                 2.712970    66.370296        2.747398
# std       1.024167                 1.085677    20.096807        0.704016
# min       1.000000                 1.000000    30.000000        1.000000
# ...

# %%
df_copy.iloc[:, 21:].describe()
# Out:
#        PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# count        2498.000000               2498.000000       2498.000000
# mean            3.148919                  2.757406          0.767414
# std             0.356080                  1.079349          0.827991
# min             3.000000                  1.000000          0.000000
# 25%             3.000000                  2.000000          0.000000
# 50%             3.000000                  3.000000          1.000000
# 75%             3.000000                  4.000000          1.000000
# max             4.000000                  4.000000          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        2498.000000            2498.000000      2498.000000
# mean           11.364692               2.777822         2.773419
# std             7.847382               1.319229         0.711414
# min             0.000000               0.000000         1.000000
# ...

# %%
df_copy = df_copy.dropna()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2351 entries, 0 to 4432
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            2351 non-null   int64
#  1   Age                       2351 non-null   float64
#  2   BusinessTravel            2351 non-null   object
#  3   DailyRate                 2351 non-null   float64
#  4   Department                2351 non-null   object
#  5   DistanceFromHome          2351 non-null   float64
#  6   Education                 2351 non-null   float64
#  7   EducationField            2351 non-null   object
#  8   EnvironmentSatisfaction   2351 non-null   float64
#  9   Gender                    2351 non-null   object
#  10  HourlyRate                2351 non-null   float64
#  11  JobInvolvement            2351 non-null   float64
#  12  JobLevel                  2351 non-null   float64
# ...

# %%
df_copy.groupby('JobRole').max().MonthlyIncome
# Out:
# JobRole
# Healthcare Representative    13966.0
# Human Resources              10725.0
# Laboratory Technician         7403.0
# Manager                      19999.0
# Manufacturing Director       13826.0
# Research Director            19973.0
# Research Scientist            9724.0
# Sales Executive              13872.0
# Sales Representative          6632.0
# Name: MonthlyIncome, dtype: float64

# %%
df_copy.reset_index(drop=True)
# Out:
#       EmployeeNumber   Age BusinessTravel  DailyRate              Department  \
# 0                104  30.0  Travel_Rarely      852.0  Research & Development
# 1               1638  38.0  Travel_Rarely      397.0  Research & Development
# 2                164  26.0  Travel_Rarely      841.0  Research & Development
# 3                395  28.0  Travel_Rarely     1117.0  Research & Development
# 4                 53  35.0  Travel_Rarely      464.0  Research & Development
# ...              ...   ...            ...        ...                     ...
# 2346            7956  29.0  Travel_Rarely     1210.0                   Sales
# 2347            7957  29.0  Travel_Rarely     1210.0                   Sales
# 2348            7958  29.0  Travel_Rarely     1210.0                   Sales
# 2349            7962  55.0  Travel_Rarely      725.0  Research & Development
# 2350            7963  55.0  Travel_Rarely      725.0  Research & Development
#
# ...

# %%
df_copy = df_copy.iloc[:, 1:].drop_duplicates().reset_index(drop=True)

# %%
sns.boxplot(x="TotalWorkingYears", data=df_copy)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears'>

# %%
sns.lmplot(x='Age', y='MonthlyIncome', data=df_copy, fit_reg=False, hue='Attrition')

# %%
sns.pairplot(df_copy[['Age', 'DistanceFromHome', 
                  'MonthlyIncome',  'PercentSalaryHike', 
                 'YearsAtCompany', 'Attrition']])

# %%
df_copya = df_copy[["Age", 'JobLevel', 'MonthlyIncome', 'OverTime', 'StockOptionLevel', 'Attrition']]
df_copya = pd.get_dummies(df_copya, columns = ['OverTime', 'Attrition'])
df_copya.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755 entries, 0 to 1754
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1755 non-null   float64
#  1   JobLevel          1755 non-null   float64
#  2   MonthlyIncome     1755 non-null   float64
#  3   StockOptionLevel  1755 non-null   float64
#  4   OverTime_No       1755 non-null   uint8
#  5   OverTime_Yes      1755 non-null   uint8
#  6   Attrition_No      1755 non-null   uint8
#  7   Attrition_Yes     1755 non-null   uint8
# dtypes: float64(4), uint8(4)
# memory usage: 61.8 KB

# %%
df_copy = df_copy[['Age', 'DistanceFromHome', 'EducationField',  'EnvironmentSatisfaction', 'JobInvolvement',  'JobLevel', 
                  'JobSatisfaction','MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'StockOptionLevel',
                 'YearsAtCompany', 'YearsInCurrentRole', 'YearsWithCurrManager', 'Attrition']]
df_copy['Attrition'].describe()
# Out:
# count     1755
# unique       2
# top         No
# freq      1172
# Name: Attrition, dtype: object

# %%
df_copy = pd.get_dummies(df_copy, columns = ['EducationField', 'OverTime', 'Attrition'])

# %%
# Stworzenie zbioru testowego i treningowego
y = df_copy['Attrition_Yes'].values
df_copy1=df_copy.drop(['Attrition_Yes','Attrition_No'], axis=1)
X = df_copy1.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# %%
def calculate_metrics (X_train, X_test, y_train, y_test, model):
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    acc_train = accuracy_score(y_train, y_pred_train)
    acc_test = accuracy_score(y_test, y_pred_test)

    F1_train = f1_score(y_train, y_pred_train)
    F1_test = f1_score(y_test, y_pred_test)

    recall_train = recall_score(y_train, y_pred_train)
    recall_test = recall_score(y_test, y_pred_test)
    wyniki = pd.DataFrame({'Accuracy':[acc_train, acc_test],
                      'F1':[F1_train, F1_test],
                      'Recall':[recall_train, recall_test]})
    wyniki.index=['train', 'test']
    return  wyniki

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score

#regresja logistyczna
lr = LogisticRegression(max_iter=1000, random_state=30)
lr.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, lr))
# Out:
#        Accuracy        F1    Recall
# train  0.672365  0.025424  0.012959
# test   0.663818  0.032787  0.016667

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=2)

clf.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, clf))
# Out:
#        Accuracy        F1    Recall
# train  0.685185  0.224561  0.138229
# test   0.672365  0.217687  0.133333

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, metric='chebyshev')
knn.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, knn))
# Out:
#        Accuracy        F1    Recall
# train  0.695869  0.372981  0.274298
# test   0.555556  0.152174  0.116667

# %%
#svm
from sklearn.svm import SVC

svm = SVC()
svm.fit(X_train,y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, svm))
# Out:
#        Accuracy   F1  Recall
# train  0.670228  0.0     0.0
# test   0.658120  0.0     0.0

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(X, y)

# print(y)
# print(y_ros)

X_train, X_test, y_train, y_test = train_test_split(
    x_ros, y_ros, test_size=0.2, random_state=0)

# %%
lr = LogisticRegression(max_iter=1000, random_state=30)
lr.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, lr))
# Out:
#        Accuracy        F1    Recall
# train  0.581867  0.565891  0.541888
# test   0.560768  0.538117  0.524017

# %%
clf = DecisionTreeClassifier(max_depth=2)

clf.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, clf))
# Out:
#        Accuracy        F1    Recall
# train  0.567467  0.472349  0.384942
# test   0.545842  0.435013  0.358079

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(max_depth=6)

rfc.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, rfc))
# Out:
#        Accuracy        F1    Recall
# train  0.713067  0.685380  0.621421
# test   0.575693  0.529551  0.489083

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='chebyshev')
knn.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, knn))
# Out:
#        Accuracy        F1    Recall
# train  0.702400  0.723214  0.773065
# test   0.513859  0.530864  0.563319

# %%
# Kroswalidacja stratyfikowana
from sklearn.model_selection import RepeatedStratifiedKFold
cv = RepeatedStratifiedKFold(n_splits=20, n_repeats=20, random_state=42)
for train_index, test_index in cv.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
#regresja logistyczna
lr = LogisticRegression(max_iter=1000, random_state=30)
lr.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, lr))
# Out:
#        Accuracy        F1    Recall
# train  0.677458  0.109272  0.059567
# test   0.678161  0.066667  0.034483

# %%
clf = DecisionTreeClassifier(max_depth=5)

clf.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, clf))
# Out:
#        Accuracy        F1    Recall
# train  0.703237  0.246575  0.146209
# test   0.643678  0.114286  0.068966

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=20, shuffle=True, random_state=42)
y = df_copy['Attrition_Yes']
X = df_copy.drop(['Attrition_Yes','Attrition_No'], axis=1)
for train, test in kf.split(X, y):
    X_train, y_train = X.iloc[train], y.iloc[train]
    X_test, y_test = X.iloc[test], y.iloc[test]

# %%
#regresja logistyczna
lr = LogisticRegression(max_iter=1000, random_state=30)
lr.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, lr))
# Out:
#        Accuracy        F1    Recall
# train  0.671463  0.045296  0.023466
# test   0.689655  0.129032  0.068966

# %%
clf = DecisionTreeClassifier(max_depth=2)
clf.fit(X_train, y_train)

print(calculate_metrics (X_train, X_test, y_train, y_test, clf))
# Out:
#        Accuracy        F1    Recall
# train  0.683453  0.209581  0.126354
# test   0.678161  0.222222  0.137931

# %%
# Liczenie korelacji między zmiennymi
count_corr=df_copy.corr()

# Heatmapa korelacji między zmiennymi
plt.figure(figsize=(20,15))
sns.heatmap(count_corr, cmap= 'RdYlGn',annot=True)
# Out:
# <AxesSubplot:>

# %%
y = df_copya['Attrition_Yes'].values
df_copy1=df_copya.drop(['Attrition_Yes','Attrition_No'], axis=1)
X = df_copy1.values

ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(X, y)

# print(y)
# print(y_ros)

X_train, X_test, y_train, y_test = train_test_split(
    x_ros, y_ros, test_size=0.1, random_state=0)

# %%
lr = LogisticRegression(max_iter=100000, random_state=30)
lr.fit(X_train, y_train)
print(calculate_metrics (X_train, X_test, y_train, y_test, lr))

clf = DecisionTreeClassifier(max_depth=5)
clf.fit(X_train, y_train)
print(calculate_metrics (X_train, X_test, y_train, y_test, clf))

rfc = RandomForestClassifier(max_depth=6)
rfc.fit(X_train, y_train)
print(calculate_metrics (X_train, X_test, y_train, y_test, rfc))
# Out:
#        Accuracy        F1    Recall
# train  0.554291  0.534653  0.510880
# test   0.565957  0.518868  0.478261
#        Accuracy        F1    Recall
# train  0.613561  0.617909  0.623463
# test   0.536170  0.515556  0.504348
#        Accuracy        F1    Recall
# train  0.659554  0.626819  0.570482
# test   0.570213  0.512077  0.460870
